# %%
import pandas as pd

# %%
local_path = r"C:\Users\ad\Desktop\Github\Personal-Study\Artificial Intelligence\파이썬 증권 데이터 분석\data\상장법인목록.xls"
krx_list = pd.read_html(local_path)

# %%
krx_list[0]["종목코드"] = krx_list[0]["종목코드"].map("{:06d}".format)
krx_list[0]
# Out:
#            회사명    종목코드                   업종  \
# 0         엠씨넥스  097520        영상 및 음향기기 제조업
# 1         아모센스  357580             전자부품 제조업
# 2         타임기술  318660       소프트웨어 개발 및 공급업
# 3          이노뎁  303530       소프트웨어 개발 및 공급업
# 4         라온테크  232680        특수 목적용 기계 제조업
# ...        ...     ...                  ...
# 2445    CJ대한통운  000120            도로 화물 운송업
# 2446     메리츠화재  000060                  보험업
# 2447        경방  000050               종합 소매업
# 2448     유수홀딩스  000700  회사 본부 및 경영 컨설팅 서비스업
# 2449  한진중공업홀딩스  003480    연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                        모바일 카메라모듈,전장 카메라모듈,블랙박스,IP 카메라  2021-07-06  12월
# 1                                             무선충전 차폐시트  2021-06-25  12월
# 2         ILS(종합군수지원), IETM(전자식기술교범), CBT(전자식교보재), 기술번역  2021-06-24  12월
# 3                                     영상인식 및 데이터플랫폼 솔루션  2021-06-18  12월
# ...
