# %%
import torch
import math

class my_opty(torch.autograd.Function):
    @staticmethod
    def forward(ctx, input):
        ctx.save_for_backward(input)
        return 0.5 * (5 * input ** 3 - 3 * input)
    @staticmethod
    def backward(ctx, grad_output):
        input, = ctx.saved_tensors
        return grad_output * 1.5 * (5 * input ** 2 - 1)

dtype = torch.float
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

x = torch.linspace(-math.pi, math.pi, 10, device=device, dtype=dtype)
y = torch.sin(x)

a = torch.full((), 0.0, device=device, dtype=dtype, requires_grad=True)
b = torch.full((), -1.0, device=device, dtype=dtype, requires_grad=True)
c = torch.full((), 0.0, device=device, dtype=dtype, requires_grad=True)
d = torch.full((), 0.3, device=device, dtype=dtype, requires_grad=True)

lr = 0.00005

for t in range(100000):
    m_o = my_opty.apply

    y_pred = a + b * m_o(c + d * x)
    mse = (y_pred - y).pow(2).sum()
    if t%1000 == 0:
        print(t)
        print("input : ", x)
        print("pred : ", y_pred)
        print("target : ",y)
        print("mse : ", mse.item())
        print("{:.5f} {:.5f} {:.5f} {:.5f}".format(a,b,c,d))
        print()

    mse.backward()
    with torch.no_grad():
        a -= lr * a.grad
        b -= lr * b.grad
        c -= lr * c.grad
        d -= lr * d.grad
        a.grad = None
        b.grad = None
        c.grad = None
        d.grad = None
# Out:
# 0
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.6792, -0.1148, -0.4265, -0.3937, -0.1542,  0.1542,  0.3937,  0.4265,
#          0.1148, -0.6792], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  2.620178461074829
# 0.00000 -1.00000 0.00000 0.30000
#
# 1000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([-0.0030, -0.3951, -0.4927, -0.3798, -0.1406,  0.1406,  0.3798,  0.4927,
#          0.3951,  0.0030], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  1.161118745803833
# 0.00000 -1.10410 0.00000 0.24627
#
# 2000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0012, -0.4280, -0.5355, -0.4132, -0.1531,  0.1531,  0.4132,  0.5355,
#          0.4280, -0.0012], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.9775625467300415
# 0.00000 -1.19987 0.00000 0.24667
#
# 3000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0052, -0.4579, -0.5746, -0.4437, -0.1644,  0.1644,  0.4437,  0.5746,
#          0.4579, -0.0052], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.8247798681259155
# 0.00000 -1.28724 0.00000 0.24699
#
# 4000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0091, -0.4852, -0.6102, -0.4716, -0.1748,  0.1748,  0.4716,  0.6102,
#          0.4852, -0.0091], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.6976017355918884
# 0.00000 -1.36696 0.00000 0.24726
#
# 5000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0126, -0.5100, -0.6427, -0.4970, -0.1842,  0.1842,  0.4970,  0.6427,
#          0.5100, -0.0126], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.5917317867279053
# 0.00000 -1.43969 0.00000 0.24749
#
# 6000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0160, -0.5326, -0.6724, -0.5202, -0.1929,  0.1929,  0.5202,  0.6724,
#          0.5326, -0.0160], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.503595232963562
# 0.00000 -1.50605 0.00000 0.24768
#
# 7000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0191, -0.5532, -0.6995, -0.5414, -0.2008,  0.2008,  0.5414,  0.6995,
#          0.5532, -0.0191], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.43022024631500244
# 0.00000 -1.56660 0.00000 0.24785
#
# 8000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0220, -0.5720, -0.7242, -0.5608, -0.2080,  0.2080,  0.5608,  0.7242,
#          0.5720, -0.0220], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.36913254857063293
# 0.00000 -1.62185 0.00000 0.24799
#
# 9000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0247, -0.5892, -0.7467, -0.5784, -0.2145,  0.2145,  0.5784,  0.7467,
#          0.5892, -0.0247], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.318273663520813
# 0.00000 -1.67226 0.00000 0.24812
#
# 10000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0272, -0.6048, -0.7673, -0.5945, -0.2205,  0.2205,  0.5945,  0.7673,
#          0.6048, -0.0272], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.2759295105934143
# 0.00000 -1.71826 0.00000 0.24822
#
# 11000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0295, -0.6190, -0.7861, -0.6092, -0.2260,  0.2260,  0.6092,  0.7861,
#          0.6190, -0.0295], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.24067477881908417
# 0.00000 -1.76023 0.00000 0.24832
#
# 12000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0316, -0.6320, -0.8032, -0.6226, -0.2310,  0.2310,  0.6226,  0.8032,
#          0.6320, -0.0316], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.21132169663906097
# 0.00000 -1.79853 0.00000 0.24840
#
# 13000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0335, -0.6439, -0.8188, -0.6349, -0.2355,  0.2355,  0.6349,  0.8188,
#          0.6439, -0.0335], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.1868819296360016
# 0.00000 -1.83347 0.00000 0.24848
#
# 14000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0353, -0.6547, -0.8331, -0.6460, -0.2397,  0.2397,  0.6460,  0.8331,
#          0.6547, -0.0353], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.1665327250957489
# 0.00000 -1.86536 0.00000 0.24854
#
# 15000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0369, -0.6646, -0.8461, -0.6562, -0.2435,  0.2435,  0.6562,  0.8461,
#          0.6646, -0.0369], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.14959004521369934
# 0.00000 -1.89445 0.00000 0.24860
#
# 16000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0384, -0.6736, -0.8580, -0.6655, -0.2470,  0.2470,  0.6655,  0.8580,
#          0.6736, -0.0384], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.13548262417316437
# 0.00000 -1.92100 0.00000 0.24865
#
# 17000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0397, -0.6818, -0.8688, -0.6740, -0.2501,  0.2501,  0.6740,  0.8688,
#          0.6818, -0.0397], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.12373693287372589
# 0.00000 -1.94523 0.00000 0.24870
#
# 18000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0410, -0.6893, -0.8787, -0.6818, -0.2530,  0.2530,  0.6818,  0.8787,
#          0.6893, -0.0410], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.1139565259218216
# 0.00000 -1.96734 0.00000 0.24874
#
# 19000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0421, -0.6961, -0.8877, -0.6888, -0.2556,  0.2556,  0.6888,  0.8877,
#          0.6961, -0.0421], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.10581297427415848
# 0.00000 -1.98751 0.00000 0.24878
#
# 20000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0432, -0.7024, -0.8960, -0.6953, -0.2580,  0.2580,  0.6953,  0.8960,
#          0.7024, -0.0432], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.09903236478567123
# 0.00000 -2.00592 0.00000 0.24881
#
# 21000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0441, -0.7081, -0.9035, -0.7012, -0.2602,  0.2602,  0.7012,  0.9035,
#          0.7081, -0.0441], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.09338673204183578
# 0.00000 -2.02271 0.00000 0.24884
#
# 22000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0450, -0.7133, -0.9103, -0.7065, -0.2622,  0.2622,  0.7065,  0.9103,
#          0.7133, -0.0450], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.08868549764156342
# 0.00000 -2.03804 0.00000 0.24887
#
# 23000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0458, -0.7180, -0.9166, -0.7114, -0.2641,  0.2641,  0.7114,  0.9166,
#          0.7180, -0.0458], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.08477212488651276
# 0.00000 -2.05202 0.00000 0.24890
#
# 24000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0465, -0.7223, -0.9223, -0.7159, -0.2657,  0.2657,  0.7159,  0.9223,
#          0.7223, -0.0465], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.08151303231716156
# 0.00000 -2.06478 0.00000 0.24892
#
# 25000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0472, -0.7263, -0.9275, -0.7200, -0.2672,  0.2672,  0.7200,  0.9275,
#          0.7263, -0.0472], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.07879853993654251
# 0.00000 -2.07643 0.00000 0.24894
#
# 26000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0478, -0.7299, -0.9322, -0.7237, -0.2686,  0.2686,  0.7237,  0.9322,
#          0.7299, -0.0478], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.07653846591711044
# 0.00000 -2.08706 0.00000 0.24896
#
# 27000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0483, -0.7331, -0.9366, -0.7271, -0.2699,  0.2699,  0.7271,  0.9366,
#          0.7331, -0.0483], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.07465814054012299
# 0.00000 -2.09675 0.00000 0.24897
#
# 28000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0489, -0.7361, -0.9405, -0.7302, -0.2711,  0.2711,  0.7302,  0.9405,
#          0.7361, -0.0489], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.07309041917324066
# 0.00000 -2.10560 0.00000 0.24899
#
# 29000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0493, -0.7389, -0.9441, -0.7330, -0.2721,  0.2721,  0.7330,  0.9441,
#          0.7389, -0.0493], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.07178650051355362
# 0.00000 -2.11367 0.00000 0.24900
#
# 30000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0497, -0.7414, -0.9474, -0.7356, -0.2731,  0.2731,  0.7356,  0.9474,
#          0.7414, -0.0497], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.07069943100214005
# 0.00000 -2.12104 0.00000 0.24901
#
# 31000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0501, -0.7436, -0.9504, -0.7380, -0.2739,  0.2739,  0.7380,  0.9504,
#          0.7436, -0.0501], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06979654729366302
# 0.00000 -2.12776 0.00000 0.24902
#
# 32000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0505, -0.7457, -0.9532, -0.7401, -0.2747,  0.2747,  0.7401,  0.9532,
#          0.7457, -0.0505], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06904231011867523
# 0.00000 -2.13390 0.00000 0.24903
#
# 33000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0508, -0.7476, -0.9557, -0.7421, -0.2755,  0.2755,  0.7421,  0.9557,
#          0.7476, -0.0508], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06841535866260529
# 0.00000 -2.13950 0.00000 0.24904
#
# 34000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0511, -0.7493, -0.9580, -0.7439, -0.2761,  0.2761,  0.7439,  0.9580,
#          0.7493, -0.0511], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.0678928941488266
# 0.00000 -2.14460 0.00000 0.24905
#
# 35000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0514, -0.7509, -0.9601, -0.7455, -0.2767,  0.2767,  0.7455,  0.9601,
#          0.7509, -0.0514], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06745877116918564
# 0.00000 -2.14926 0.00000 0.24906
#
# 36000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0516, -0.7524, -0.9620, -0.7470, -0.2773,  0.2773,  0.7470,  0.9620,
#          0.7524, -0.0516], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06709744036197662
# 0.00000 -2.15350 0.00000 0.24907
#
# 37000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0518, -0.7537, -0.9637, -0.7484, -0.2778,  0.2778,  0.7484,  0.9637,
#          0.7537, -0.0518], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06679481267929077
# 0.00000 -2.15740 0.00000 0.24907
#
# 38000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0520, -0.7549, -0.9653, -0.7496, -0.2783,  0.2783,  0.7496,  0.9653,
#          0.7549, -0.0520], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06654483824968338
# 0.00000 -2.16093 0.00000 0.24908
#
# 39000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0522, -0.7560, -0.9667, -0.7507, -0.2787,  0.2787,  0.7507,  0.9667,
#          0.7560, -0.0522], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06633605062961578
# 0.00000 -2.16415 0.00000 0.24908
#
# 40000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0524, -0.7570, -0.9680, -0.7518, -0.2791,  0.2791,  0.7518,  0.9680,
#          0.7570, -0.0524], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06616184860467911
# 0.00000 -2.16710 0.00000 0.24909
#
# 41000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0526, -0.7579, -0.9692, -0.7527, -0.2794,  0.2794,  0.7527,  0.9692,
#          0.7579, -0.0526], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06601685285568237
# 0.00000 -2.16980 0.00000 0.24909
#
# 42000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0527, -0.7587, -0.9703, -0.7536, -0.2797,  0.2797,  0.7536,  0.9703,
#          0.7587, -0.0527], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06589637696743011
# 0.00000 -2.17225 0.00000 0.24910
#
# 43000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0528, -0.7595, -0.9713, -0.7543, -0.2800,  0.2800,  0.7543,  0.9713,
#          0.7595, -0.0528], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06579600274562836
# 0.00000 -2.17448 0.00000 0.24910
#
# 44000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0530, -0.7602, -0.9723, -0.7551, -0.2803,  0.2803,  0.7551,  0.9723,
#          0.7602, -0.0530], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06571215391159058
# 0.00000 -2.17653 0.00000 0.24910
#
# 45000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0531, -0.7608, -0.9731, -0.7557, -0.2806,  0.2806,  0.7557,  0.9731,
#          0.7608, -0.0531], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06564140319824219
# 0.00000 -2.17842 0.00000 0.24911
#
# 46000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0532, -0.7614, -0.9738, -0.7563, -0.2808,  0.2808,  0.7563,  0.9738,
#          0.7614, -0.0532], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06558448821306229
# 0.00000 -2.18009 0.00000 0.24911
#
# 47000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0532, -0.7619, -0.9745, -0.7569, -0.2810,  0.2810,  0.7569,  0.9745,
#          0.7619, -0.0532], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06553615629673004
# 0.00000 -2.18165 0.00000 0.24911
#
# 48000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0533, -0.7624, -0.9752, -0.7574, -0.2812,  0.2812,  0.7574,  0.9752,
#          0.7624, -0.0533], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06549547612667084
# 0.00000 -2.18308 0.00000 0.24911
#
# 49000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0534, -0.7628, -0.9757, -0.7578, -0.2813,  0.2813,  0.7578,  0.9757,
#          0.7628, -0.0534], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06546251475811005
# 0.00000 -2.18435 0.00000 0.24912
#
# 50000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0535, -0.7632, -0.9763, -0.7582, -0.2815,  0.2815,  0.7582,  0.9763,
#          0.7632, -0.0535], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06543434411287308
# 0.00000 -2.18554 0.00000 0.24912
#
# 51000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0535, -0.7636, -0.9768, -0.7586, -0.2816,  0.2816,  0.7586,  0.9768,
#          0.7636, -0.0535], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06541110575199127
# 0.00000 -2.18662 0.00000 0.24912
#
# 52000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0536, -0.7639, -0.9772, -0.7589, -0.2817,  0.2817,  0.7589,  0.9772,
#          0.7639, -0.0536], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06539212167263031
# 0.00000 -2.18757 0.00000 0.24912
#
# 53000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0536, -0.7642, -0.9776, -0.7593, -0.2819,  0.2819,  0.7593,  0.9776,
#          0.7642, -0.0536], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06537505984306335
# 0.00000 -2.18852 0.00000 0.24912
#
# 54000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0537, -0.7645, -0.9780, -0.7595, -0.2820,  0.2820,  0.7595,  0.9780,
#          0.7645, -0.0537], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.0653623715043068
# 0.00000 -2.18930 0.00000 0.24912
#
# 55000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0537, -0.7647, -0.9783, -0.7598, -0.2821,  0.2821,  0.7598,  0.9783,
#          0.7647, -0.0537], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06535151600837708
# 0.00000 -2.19001 0.00000 0.24912
#
# 56000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0538, -0.7650, -0.9786, -0.7600, -0.2822,  0.2822,  0.7600,  0.9786,
#          0.7650, -0.0538], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06534163653850555
# 0.00000 -2.19073 0.00000 0.24913
#
# 57000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0538, -0.7652, -0.9789, -0.7603, -0.2823,  0.2823,  0.7603,  0.9789,
#          0.7652, -0.0538], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06533315777778625
# 0.00000 -2.19142 0.00000 0.24913
#
# 58000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0538, -0.7654, -0.9791, -0.7605, -0.2823,  0.2823,  0.7605,  0.9791,
#          0.7654, -0.0538], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06532775610685349
# 0.00000 -2.19189 0.00000 0.24913
#
# 59000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0539, -0.7655, -0.9793, -0.7606, -0.2824,  0.2824,  0.7606,  0.9793,
#          0.7655, -0.0539], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06532274186611176
# 0.00000 -2.19237 0.00000 0.24913
#
# 60000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0539, -0.7657, -0.9796, -0.7608, -0.2824,  0.2824,  0.7608,  0.9796,
#          0.7657, -0.0539], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06531812995672226
# 0.00000 -2.19285 0.00000 0.24913
#
# 61000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0539, -0.7658, -0.9798, -0.7610, -0.2825,  0.2825,  0.7610,  0.9798,
#          0.7658, -0.0539], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06531402468681335
# 0.00000 -2.19333 0.00000 0.24913
#
# 62000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0540, -0.7660, -0.9800, -0.7611, -0.2826,  0.2826,  0.7611,  0.9800,
#          0.7660, -0.0540], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06531019508838654
# 0.00000 -2.19380 0.00000 0.24913
#
# 63000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0540, -0.7661, -0.9801, -0.7612, -0.2826,  0.2826,  0.7612,  0.9801,
#          0.7661, -0.0540], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06530797481536865
# 0.00000 -2.19412 0.00000 0.24913
#
# 64000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0540, -0.7662, -0.9802, -0.7613, -0.2826,  0.2826,  0.7613,  0.9802,
#          0.7662, -0.0540], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.0653064027428627
# 0.00000 -2.19436 0.00000 0.24913
#
# 65000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0540, -0.7663, -0.9803, -0.7614, -0.2827,  0.2827,  0.7614,  0.9803,
#          0.7663, -0.0540], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06530478596687317
# 0.00000 -2.19460 0.00000 0.24913
#
# 66000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0540, -0.7663, -0.9804, -0.7615, -0.2827,  0.2827,  0.7615,  0.9804,
#          0.7663, -0.0540], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06530342996120453
# 0.00000 -2.19484 0.00000 0.24913
#
# 67000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0540, -0.7664, -0.9805, -0.7616, -0.2827,  0.2827,  0.7616,  0.9805,
#          0.7664, -0.0540], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06530214101076126
# 0.00000 -2.19508 0.00000 0.24913
#
# 68000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0540, -0.7665, -0.9807, -0.7617, -0.2828,  0.2828,  0.7617,  0.9807,
#          0.7665, -0.0540], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06530099362134933
# 0.00000 -2.19532 0.00000 0.24913
#
# 69000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0541, -0.7666, -0.9808, -0.7617, -0.2828,  0.2828,  0.7617,  0.9808,
#          0.7666, -0.0541], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06529995054006577
# 0.00000 -2.19555 0.00000 0.24913
#
# 70000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0541, -0.7667, -0.9809, -0.7618, -0.2828,  0.2828,  0.7618,  0.9809,
#          0.7667, -0.0541], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06529907882213593
# 0.00000 -2.19579 0.00000 0.24913
#
# 71000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0541, -0.7668, -0.9810, -0.7619, -0.2829,  0.2829,  0.7619,  0.9810,
#          0.7668, -0.0541], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.0652981698513031
# 0.00000 -2.19603 0.00000 0.24913
#
# 72000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0541, -0.7668, -0.9811, -0.7620, -0.2829,  0.2829,  0.7620,  0.9811,
#          0.7668, -0.0541], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06529739499092102
# 0.00000 -2.19627 0.00000 0.24913
#
# 73000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0541, -0.7669, -0.9812, -0.7621, -0.2829,  0.2829,  0.7621,  0.9812,
#          0.7669, -0.0541], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06529663503170013
# 0.00000 -2.19651 0.00000 0.24914
#
# 74000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0541, -0.7669, -0.9812, -0.7621, -0.2829,  0.2829,  0.7621,  0.9812,
#          0.7669, -0.0541], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06529654562473297
# 0.00000 -2.19657 0.00000 0.24914
#
# 75000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0541, -0.7669, -0.9812, -0.7621, -0.2829,  0.2829,  0.7621,  0.9812,
#          0.7669, -0.0541], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06529654562473297
# 0.00000 -2.19657 0.00000 0.24914
#
# 76000
# input :  tensor([-3.1416, -2.4435, -1.7453, -1.0472, -0.3491,  0.3491,  1.0472,  1.7453,
#          2.4435,  3.1416], device='cuda:0')
# pred :  tensor([ 0.0541, -0.7669, -0.9812, -0.7621, -0.2829,  0.2829,  0.7621,  0.9812,
#          0.7669, -0.0541], device='cuda:0', grad_fn=<AddBackward0>)
# target :  tensor([ 8.7423e-08, -6.4279e-01, -9.8481e-01, -8.6603e-01, -3.4202e-01,
#          3.4202e-01,  8.6603e-01,  9.8481e-01,  6.4279e-01, -8.7423e-08],
#        device='cuda:0')
# mse :  0.06529654562473297
# 0.00000 -2.19657 0.00000 0.24914
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-99-3579d889a67a> in <module>()
#      41     mse.backward()
#      42     with torch.no_grad():
# ---> 43         a -= lr * a.grad
#      44         b -= lr * b.grad
#      45         c -= lr * c.grad
#
# KeyboardInterrupt:
